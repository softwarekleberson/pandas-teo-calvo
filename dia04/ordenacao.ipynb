# %%
import pandas as pd

# %%
df = pd.read_csv('../data/clientes.csv', sep=';')

# %%
# sort_values = ordena os elementos
# by = serie que está sendo usada para ordenar
# ascending = ordenar do maior para menor
# head = quantidade de elementos que eu quero
df.sort_values(by="qtdePontos", ascending=False).head(5)
# Out:
#                                  idCliente  flEmail  flTwitch  flYouTube  \
# 1     000ff655-fa9f-4baa-a108-47f581ec52a1        0         0          0
# 3837  d7f7eb75-4f0b-4d15-960d-8efe5ca7dd7e        0         0          0
# 790   2a9d4ba3-4c58-47f9-8dc4-6f9cb50be1b1        1         1          0
# 2263  803debdb-8136-4cb5-af29-dcd8db36bf2c        0         1          0
# 1464  520ec5df-4362-4dc5-8652-908676138114        0         1          0
#
#       flBlueSky  flInstagram  qtdePontos                DtCriacao  \
# 1             0            0       25086  2024-02-01 00:00:00.000
# 3837          0            0       19628  2025-03-07 12:36:50.254
# 790           0            0       19438  2025-03-07 12:59:11.756
# 2263          0            0       16246  2025-02-28 13:19:26.475
# 1464          0            0       15536  2024-11-21 11:57:13.065
#
#                 DtAtualizacao
# 1     2025-09-26 13:28:37.697
# 3837  2025-12-12 12:14:18.672
# 790   2025-12-12 12:12:10.372
# ...
