# %%
import pandas as pd

# %%
idades = [23, 45, 12, 67, 34, 89, 21, 38, 56, 72]
idades = pd.Series(idades)
idades
# Out:
# 0    23
# 1    45
# 2    12
# 3    67
# 4    34
# 5    89
# 6    21
# 7    38
# 8    56
# 9    72
# dtype: int64

# %%
idades.describe()
# Out:
# count    10.000000
# mean     45.700000
# std      24.908945
# min      12.000000
# 25%      25.750000
# 50%      41.500000
# 75%      64.250000
# max      89.000000
# dtype: float64

# %%
idades.min()
# Out:
# 12

# %%
idades.max()
# Out:
# 89

# %%
idades.mean()
# Out:
# 45.7

# %%
idades.sum()
# Out:
# 457
