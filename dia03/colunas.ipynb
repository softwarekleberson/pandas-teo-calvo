# %%
import pandas as pd

# %%
df_transacoes = pd.read_csv('../data/transacoes.csv', sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_transacoes = pd.read_csv('../data/transacoes.csv', sep=';')
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df_transacoes.shape
# Out:
# (279566, 5)

# %%
df_transacoes.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279566 entries, 0 to 279565
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   IdTransacao        279566 non-null  object
#  1   IdCliente          279566 non-null  object
#  2   DtCriacao          279566 non-null  object
#  3   QtdePontos         279566 non-null  int64
#  4   DescSistemaOrigem  279566 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 81.3 MB

# %%
df_transacoes.dtypes
# Out:
# IdTransacao          object
# IdCliente            object
# DtCriacao            object
# QtdePontos            int64
# DescSistemaOrigem    object
# dtype: object

# %%
df_transacoes.columns
# Out:
# Index(['IdTransacao', 'IdCliente', 'DtCriacao', 'QtdePontos',
#        'DescSistemaOrigem'],
#       dtype='object')

# %%
rename_colunas = {
    'QtdePontos': 'QuantidadePontos',
    'DtCriacao': 'DataCriacao'
}

df_transacoes.rename(columns=rename_colunas, inplace=True)

# %%
df_transacoes
# Out:
#                                  IdTransacao  \
# 0       0000520a-a4e5-4977-b360-17be62fa0f2b
# 1       000060e8-aa76-4286-a8d7-f30e6fa47edd
# 2       000095de-3daa-4cfb-a0ae-e7b2c8bc3c9b
# 3       0000c010-a592-46f7-8b0b-6f841bee64ba
# 4       0000dfbb-e14e-4ea7-a57f-60236869fffe
# ...                                      ...
# 279561  ffff45c7-83dc-4fa9-82b5-b41352093596
# 279562  ffff52de-13fb-4405-a797-fddb5b4a48c5
# 279563  ffffb5ab-047e-43e4-bab3-ee2d19e9b7db
# 279564  ffffc72e-d882-47f0-b933-cfd92c7e6621
# 279565  fffff928-9a18-4741-a516-3a92351d1d72
#
#                                    IdCliente              DataCriacao  \
# 0       24782f0b-4683-4f35-976a-ea21d6714ba6  2025-09-17 12:28:41.864
# 1       252a0923-3f79-45bb-b664-3040235c6c58  2024-07-23 12:49:49.874
# 2       30f45a6d-ada5-4a17-8338-710e414eb6c6  2025-09-17 13:38:57.479
# 3       65662aff-44d6-4f06-b9d9-07445c6e5943  2025-10-03 12:23:39.779
# ...

# %%
# Lista de colunas específicas, dentro de uma outra lista
df_transacoes[['IdCliente','DataCriacao']].head()
# Out:
#                               IdCliente              DataCriacao
# 0  24782f0b-4683-4f35-976a-ea21d6714ba6  2025-09-17 12:28:41.864
# 1  252a0923-3f79-45bb-b664-3040235c6c58  2024-07-23 12:49:49.874
# 2  30f45a6d-ada5-4a17-8338-710e414eb6c6  2025-09-17 13:38:57.479
# 3  65662aff-44d6-4f06-b9d9-07445c6e5943  2025-10-03 12:23:39.779
# 4  5f8fcbe0-6014-43f8-8b83-38cf2f4887b3  2024-02-20 13:21:45.613

# %%
# Ordenar colunas em ordem alfabética
colunas = list(df_transacoes.columns)
colunas.sort()
colunas

df_transacoes = df_transacoes[colunas]
df_transacoes
# Out:
#                     DataCriacao DescSistemaOrigem  \
# 0       2025-09-17 12:28:41.864            twitch
# 1       2024-07-23 12:49:49.874            twitch
# 2       2025-09-17 13:38:57.479            twitch
# 3       2025-10-03 12:23:39.779            twitch
# 4       2024-02-20 13:21:45.613            twitch
# ...                         ...               ...
# 279561  2025-01-03 12:59:27.229            twitch
# 279562  2024-02-24 12:22:26.313            twitch
# 279563  2024-08-16 13:09:42.576            twitch
# 279564  2024-02-06 11:51:24.788            twitch
# 279565  2024-08-21 14:13:31.788            twitch
#
#                                    IdCliente  \
# 0       24782f0b-4683-4f35-976a-ea21d6714ba6
# 1       252a0923-3f79-45bb-b664-3040235c6c58
# 2       30f45a6d-ada5-4a17-8338-710e414eb6c6
# 3       65662aff-44d6-4f06-b9d9-07445c6e5943
# 4       5f8fcbe0-6014-43f8-8b83-38cf2f4887b3
# ...                                      ...
# ...
